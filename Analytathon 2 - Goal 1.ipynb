# %% [markdown]
# <h1 style="color:Red">Goal 1 - Classification of bird songs based on the spectrograms provided</h1>

# %% [markdown]
# **Author: Onkar Rajendra Jadhav**
#
# **Date: April 23th, 2023**

# %% [markdown]
# <h3 style="color:Purple">Importing Libraries</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
from torch import stack, LongTensor
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split

import os
import cv2
from sklearn import metrics # confusion matrix

# %%
# pip install opencv-python-headless

# %% [markdown]
# **Author: Onkar Rajendra Jadhav**
#
# **Date: April 23th, 2023**

# %% [markdown]
# <h3 style="color:purple">Step 1: Loading the spectrograms and preprocessing them (re-sizing and normalizing)</h3>

# %%
from sklearn.preprocessing import LabelEncoder

# Setting random seed
torch.manual_seed(99)
np.random.seed(99)

# Define the folder paths and corresponding labels
spectLocation = ["E:/Masters/DSA8023/Analytathon 2/greypartridge/greypartridgespec", "E:/Masters/DSA8023/Analytathon 2/stockdove/stockdovespec", "E:/Masters/DSA8023/Analytathon 2/turtledove/turtledovespec", "E:/Masters/DSA8023/Analytathon 2/yellowhammer/yellowhammerspec"]
birdLables = np.array(['greypartridge']*1000 + ['stockdove']*1000 + ['turtledove']*1000 + ['yellowhammer']*1000)

labelEncoder = LabelEncoder()
imageLables = labelEncoder.fit_transform(birdLables)

# Below code loads the images from the folder paths mentioned above and then converts them to a numpy array

spectData = []
for fpath in spectLocation:
    for fname in os.listdir(fpath):
        if fname.endswith(".png"): # check files ending with '.png'
            file_path_temp = os.path.join(fpath, fname)
            img = cv2.imread(file_path_temp, 0)
            imageResized = cv2.resize(img, (128, 128))  # resize each spectrogram to the same shape
            spectData.append(imageResized)
spectData = np.array(spectData)

# Normalize the image pixel values to be between 0 and 1
spectDataNorm = spectData / 255.0

# %% [markdown]
# **Author: Onkar Rajendra Jadhav**
#
# **Date: April 23th, 2023**

# %%
# Displaying loaded spectrograms 
countSpect = min(len(spectDataNorm), 10) # displaying first 10 spectrograms
countCols = 4
countRows = int(np.ceil(countSpect / countCols))

fig, axs = plt.subplots(countRows, countCols, figsize = (15,12))

for i, ax in enumerate(axs.flat):
        if i < countSpect:
            ax.imshow(spectDataNorm[i], cmap = "gray")
            ax.set_title(f"Spectrogram {i+1} / {birdLables[i]}") # spectogram number / bird species
        else:
            ax.axis("off")
            
# plt.tight_layout()
plt.show()

# %% [markdown]
# **Author: Onkar Rajendra Jadhav**
#
# **Date: April 23th, 2023**

# %% [markdown]
# <h3 style="color:purple">Step 2: Spliting the data into training and test/validation sets</h3>

# %%
# setting random seed
torch.manual_seed(99)
np.random.seed(99)

# Split the data into training and validation sets

trainSpect, testSpect, trainLabels, testLabels = train_test_split(spectDataNorm, imageLables, test_size=0.2, random_state=42)
    
trainSpect = torch.from_numpy(trainSpect).float()
trainLabels = torch.from_numpy(trainLabels).long()

testSpect = torch.from_numpy(testSpect).float()
testLabels = torch.from_numpy(testLabels).long()

# new dimension is added to the tensor to make the tensor compatible with the input of CNN
trainSpect = trainSpect.unsqueeze(1)
testSpect = testSpect.unsqueeze(1)

# train and test data sets are combined with their labels
trainDataset = TensorDataset(trainSpect, trainLabels)
testDataset = TensorDataset(testSpect, testLabels)

# data loaded into batches of 128 and shuffled for training
trainLoader = DataLoader(trainDataset, batch_size = 128, shuffle = True)
testLoader = DataLoader(testDataset, batch_size = 128, shuffle = False)

# Print the shape of the training and validation sets
print("Training set shape:", trainSpect.shape, trainLabels.shape)
print("Test or Validation set shape:", testSpect.shape, testLabels.shape)
# Out:
# Training set shape: torch.Size([3200, 1, 128, 128]) torch.Size([3200])
# Test or Validation set shape: torch.Size([800, 1, 128, 128]) torch.Size([800])

# %% [markdown]
# **Author: Onkar Rajendra Jadhav**
#
# **Date: April 23th, 2023**

# %% [markdown]
# <h3 style="color:purple">Step 3: Build a Model (Convolutional Neural Network)</h3>

# %%
# building a CNN model

classesCount = len(np.unique(imageLables)) # 4

class CNN_Image(nn.Module):
    def __init__(self, inChannels):
        super(CNN_Image, self).__init__()
        
        self.cnn_image = nn.Sequential(
            nn.Conv2d(inChannels, 16, 3, stride = 1, padding =1),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(inplace = True),
            nn.MaxPool2d(2),
            nn.Dropout(0.5),
            nn.Conv2d(16, 32, 3, stride = 1, padding =1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(inplace = True),
            nn.MaxPool2d(2),
            nn.Dropout(0.5),
            nn.Conv2d(32, 32, 3, stride = 1, padding =1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(inplace = True),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Dropout(0.5),
        )
        self.fc = nn.Sequential(
            nn.Linear(8192, 200),
            nn.BatchNorm1d(200),
            nn.LeakyReLU(inplace = True),
            nn.Linear(200, classesCount)
        )
        
    def forward(self, x):
        out = self.cnn_image(x)
        out = self.fc(out)
        
        return out

# %% [markdown]
# **Author: Sai Chaitanya Mondi**
#
# **Date: April 23th, 2023**

# %% [markdown]
# <h3 style="color:purple">Step 4: Define a train function</h3>

# %%
num_epochs = 5
classesCount = len(np.unique(imageLables)) # 4

def train(model, trainLoader, testLoader, num_epochs, optimizer):
    criterion = nn.CrossEntropyLoss()
    model.train()
    
    epochs, epoch_loss, trainAcc, testAcc = [], [], [], []
    
    for n in range(num_epochs):
        trainLoss = 0
        
        for i, data in enumerate(trainLoader):
            inputs, labels = data
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            trainLoss += loss.item()
        
        epoch_loss.append(trainLoss / len(trainLoader))
        trainAcc.append(getAccuracy(model, trainLoader))
        testAcc.append(getAccuracy(model, testLoader))
        epochs.append(n)
        
        print(f"Epoch {n+1}: Training Loss: {epoch_loss[-1]:>0.3f}")
        print(f"Training Accuracy: {100 * trainAcc[-1]: >0.2f}%")
        print(f"Testing Accuracy: {100 * testAcc[-1]: >0.2f}%")
        print("-------------------------------")
        
    # plotting
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 7))
    
    ax1.set_title("Training Curve")
    ax1.plot(epoch_loss, label="Train")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    
    ax2.set_title("Comparison between Train and Test Accuracy Curves")
    ax2.plot(epochs, trainAcc, label="Train")
    ax2.plot(epochs, testAcc, label="Test")
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("Accuracy")
    ax2.legend(loc="best")
        
        
def getAccuracy(model, dataLoader):
    correct, total = 0, 0
    model.eval()
    
    with torch.no_grad():
        for data in dataLoader:
            inputs, labels = data
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total
    
    return accuracy

# %% [markdown]
# **Author: Sai Chaitanya Mondi**
#
# **Date: April 23th, 2023**

# %% [markdown]
# <h3 style="color:purple">Step 5: Run and check for results</h3>

# %%
model = CNN_Image(inChannels=1)
optimizer = optim.Adam(model.parameters(), lr = 2e-4, weight_decay = 3e-3)
train(model, trainLoader, testLoader, 15, optimizer)
print("Done!")
# Out:
# Epoch 1: Training Loss: 1.081
# Training Accuracy: 24.72%
# Testing Accuracy: 26.12%
# -------------------------------
# Epoch 2: Training Loss: 1.226
# Training Accuracy: 53.28%
# Testing Accuracy: 54.00%
# -------------------------------
# Epoch 3: Training Loss: 0.883
# Training Accuracy: 73.50%
# Testing Accuracy: 73.25%
# -------------------------------
# Epoch 4: Training Loss: 0.695
# Training Accuracy: 75.06%
# Testing Accuracy: 74.62%
# -------------------------------
# Epoch 5: Training Loss: 0.628
# Training Accuracy: 79.41%
# Testing Accuracy: 77.75%
# -------------------------------
# Epoch 6: Training Loss: 0.561
# Training Accuracy: 80.00%
# Testing Accuracy: 78.00%
# -------------------------------
# Epoch 7: Training Loss: 0.535
# Training Accuracy: 81.72%
# Testing Accuracy: 81.00%
# -------------------------------
# Epoch 8: Training Loss: 0.511
# Training Accuracy: 84.88%
# Testing Accuracy: 83.00%
# -------------------------------
# Epoch 9: Training Loss: 0.473
# Training Accuracy: 85.19%
# Testing Accuracy: 82.75%
# -------------------------------
# Epoch 10: Training Loss: 0.459
# Training Accuracy: 85.00%
# Testing Accuracy: 81.38%
# -------------------------------
# Epoch 11: Training Loss: 0.433
# Training Accuracy: 85.53%
# Testing Accuracy: 81.12%
# -------------------------------
# Epoch 12: Training Loss: 0.422
# Training Accuracy: 86.09%
# Testing Accuracy: 83.88%
# -------------------------------
# Epoch 13: Training Loss: 0.385
# Training Accuracy: 85.84%
# Testing Accuracy: 83.75%
# -------------------------------
# Epoch 14: Training Loss: 0.380
# Training Accuracy: 88.62%
# Testing Accuracy: 83.88%
# -------------------------------
# Epoch 15: Training Loss: 0.353
# Training Accuracy: 87.88%
# Testing Accuracy: 84.50%
# -------------------------------
# Done!

# %% [markdown]
# Model Interpretation: Our model is performing well with good accuracy. From the second plot above, as the training curve <span style="color:blue">(Blue)</span> is slightly higher than the validation curve <span style="color:orange">(Orange)</span>, we can interpret that the model is slightly overfitting. This can be improved by increasing the size of training data, increasing dropouts and weight decay term.

# %% [markdown]
# **Author: Sai Chaitanya Mondi**
#
# **Date: April 23th, 2023**

# %% [markdown]
# <h3 style="color:purple">Step 6: Confusion Matrix</h3>

# %%
yTrue = []
yPred = []

with torch.no_grad():
    for data in testLoader:
        inputs, labels = data
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        yTrue += labels.numpy().tolist()
        yPred += predicted.numpy().tolist()
        

# plotting
fig, ax = plt.subplots(ncols=2, figsize=(18, 7))

# first plot
disp = metrics.ConfusionMatrixDisplay.from_predictions(yTrue, yPred, display_labels=np.unique(birdLables), normalize='true')
disp.plot(ax=ax[0], cmap=plt.cm.Blues, xticks_rotation='vertical', values_format='.2f')
ax[0].set_title('Confusion matrix - Proportion', fontsize=14, fontweight='bold')

# second plot
confMat = metrics.confusion_matrix(yTrue, yPred)
dispMat = metrics.ConfusionMatrixDisplay(confusion_matrix=confMat, display_labels=np.unique(birdLables))
dispMat.plot(ax=ax[1], cmap='summer')
ax[1].set_title('Confusion matrix - Predicted Number', fontsize=14, fontweight='bold')
ax[1].set_xticklabels(np.unique(birdLables), rotation='vertical')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Author: Sai Chaitanya Mondi**
#
# **Date: April 23th, 2023**

# %% [markdown]
# <h3 style="color:purple">Performance Metrics</h3>

# %%
# F1 Score
f1Score = metrics.f1_score(yTrue, yPred, average = "weighted")
print(f"F1 Score is {f1Score:0.2f}, means the model is correctly identifying the classes of the given dataset")
print(f"\n")

# Accuracy
modelAcc = metrics.accuracy_score(yTrue, yPred)
print(f"Model's accuracy is {modelAcc * 100:0.2f}%")
print(f"\n")

# Classification Report
classReport = metrics.classification_report(yTrue, yPred)
print(f"The Classification Report is as below:\n {classReport}")
# Out:
# F1 Score is 0.84, means the model is correctly identifying the classes of the given dataset
#
#
# Model's accuracy is 84.50%
#
#
# The Classification Report is as below:
#                precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       209
#            1       0.78      0.84      0.81       213
#            2       0.92      0.91      0.92       194
#            3       0.88      0.75      0.81       184
#
#     accuracy                           0.84       800
#    macro avg       0.85      0.84      0.85       800
# weighted avg       0.85      0.84      0.84       800

# %% [markdown]
# **Author: Sai Chaitanya Mondi**
#
# **Date: April 23th, 2023**

# %% [markdown]
# <h3 style="color:purple">Running the model for 70 epochs to get more information on the curve</h3>

# %%
model_temp = CNN_Image(inChannels=1)
optimizer = optim.Adam(model_temp.parameters(), lr = 2e-4, weight_decay = 3e-3)
train(model_temp, trainLoader, testLoader, 70, optimizer)
print("Done!")
# Out:
# Epoch 1: Training Loss: 1.064
# Training Accuracy: 24.72%
# Testing Accuracy: 26.12%
# -------------------------------
# Epoch 2: Training Loss: 1.368
# Training Accuracy: 54.06%
# Testing Accuracy: 53.00%
# -------------------------------
# Epoch 3: Training Loss: 1.003
# Training Accuracy: 66.28%
# Testing Accuracy: 64.25%
# -------------------------------
# Epoch 4: Training Loss: 0.752
# Training Accuracy: 77.00%
# Testing Accuracy: 77.50%
# -------------------------------
# Epoch 5: Training Loss: 0.642
# Training Accuracy: 77.91%
# Testing Accuracy: 77.75%
# -------------------------------
# Epoch 6: Training Loss: 0.581
# Training Accuracy: 81.81%
# Testing Accuracy: 81.75%
# -------------------------------
# Epoch 7: Training Loss: 0.544
# Training Accuracy: 82.00%
# Testing Accuracy: 81.00%
# -------------------------------
# Epoch 8: Training Loss: 0.524
# Training Accuracy: 82.50%
# Testing Accuracy: 81.75%
# -------------------------------
# Epoch 9: Training Loss: 0.488
# Training Accuracy: 84.44%
# Testing Accuracy: 83.25%
# -------------------------------
# Epoch 10: Training Loss: 0.460
# Training Accuracy: 83.44%
# Testing Accuracy: 82.00%
# -------------------------------
# Epoch 11: Training Loss: 0.432
# Training Accuracy: 86.44%
# Testing Accuracy: 84.50%
# -------------------------------
# Epoch 12: Training Loss: 0.412
# Training Accuracy: 87.00%
# Testing Accuracy: 85.25%
# -------------------------------
# Epoch 13: Training Loss: 0.388
# Training Accuracy: 88.12%
# Testing Accuracy: 84.88%
# -------------------------------
# Epoch 14: Training Loss: 0.365
# Training Accuracy: 87.94%
# Testing Accuracy: 85.38%
# -------------------------------
# Epoch 15: Training Loss: 0.355
# Training Accuracy: 87.12%
# Testing Accuracy: 84.50%
# -------------------------------
# Epoch 16: Training Loss: 0.342
# Training Accuracy: 88.66%
# Testing Accuracy: 85.00%
# -------------------------------
# Epoch 17: Training Loss: 0.326
# Training Accuracy: 87.16%
# Testing Accuracy: 83.00%
# -------------------------------
# Epoch 18: Training Loss: 0.309
# Training Accuracy: 91.34%
# Testing Accuracy: 85.88%
# -------------------------------
# Epoch 19: Training Loss: 0.291
# Training Accuracy: 90.47%
# Testing Accuracy: 85.00%
# -------------------------------
# Epoch 20: Training Loss: 0.266
# Training Accuracy: 91.69%
# Testing Accuracy: 86.88%
# -------------------------------
# Epoch 21: Training Loss: 0.256
# Training Accuracy: 92.19%
# Testing Accuracy: 88.00%
# -------------------------------
# Epoch 22: Training Loss: 0.249
# Training Accuracy: 92.34%
# Testing Accuracy: 87.50%
# -------------------------------
# Epoch 23: Training Loss: 0.216
# Training Accuracy: 92.62%
# Testing Accuracy: 87.75%
# -------------------------------
# Epoch 24: Training Loss: 0.217
# Training Accuracy: 93.34%
# Testing Accuracy: 87.75%
# -------------------------------
# Epoch 25: Training Loss: 0.190
# Training Accuracy: 93.97%
# Testing Accuracy: 87.88%
# -------------------------------
# Epoch 26: Training Loss: 0.191
# Training Accuracy: 94.50%
# Testing Accuracy: 87.25%
# -------------------------------
# Epoch 27: Training Loss: 0.178
# Training Accuracy: 93.81%
# Testing Accuracy: 88.00%
# -------------------------------
# Epoch 28: Training Loss: 0.168
# Training Accuracy: 95.00%
# Testing Accuracy: 86.88%
# -------------------------------
# Epoch 29: Training Loss: 0.150
# Training Accuracy: 93.78%
# Testing Accuracy: 87.00%
# -------------------------------
# Epoch 30: Training Loss: 0.145
# Training Accuracy: 96.34%
# Testing Accuracy: 88.75%
# -------------------------------
# Epoch 31: Training Loss: 0.129
# Training Accuracy: 96.56%
# Testing Accuracy: 88.88%
# -------------------------------
# Epoch 32: Training Loss: 0.147
# Training Accuracy: 96.28%
# Testing Accuracy: 88.50%
# -------------------------------
# Epoch 33: Training Loss: 0.161
# Training Accuracy: 94.69%
# Testing Accuracy: 87.25%
# -------------------------------
# Epoch 34: Training Loss: 0.154
# Training Accuracy: 96.16%
# Testing Accuracy: 88.88%
# -------------------------------
# Epoch 35: Training Loss: 0.118
# Training Accuracy: 96.69%
# Testing Accuracy: 88.38%
# -------------------------------
# Epoch 36: Training Loss: 0.099
# Training Accuracy: 97.66%
# Testing Accuracy: 89.12%
# -------------------------------
# Epoch 37: Training Loss: 0.088
# Training Accuracy: 97.84%
# Testing Accuracy: 89.12%
# -------------------------------
# Epoch 38: Training Loss: 0.091
# Training Accuracy: 97.62%
# Testing Accuracy: 88.00%
# -------------------------------
# Epoch 39: Training Loss: 0.083
# Training Accuracy: 98.38%
# Testing Accuracy: 89.50%
# -------------------------------
# Epoch 40: Training Loss: 0.074
# Training Accuracy: 98.84%
# Testing Accuracy: 89.25%
# -------------------------------
# Epoch 41: Training Loss: 0.071
# Training Accuracy: 97.97%
# Testing Accuracy: 89.25%
# -------------------------------
# Epoch 42: Training Loss: 0.070
# Training Accuracy: 98.22%
# Testing Accuracy: 88.88%
# -------------------------------
# Epoch 43: Training Loss: 0.062
# Training Accuracy: 98.84%
# Testing Accuracy: 89.25%
# -------------------------------
# Epoch 44: Training Loss: 0.057
# Training Accuracy: 98.59%
# Testing Accuracy: 88.88%
# -------------------------------
# Epoch 45: Training Loss: 0.052
# Training Accuracy: 99.38%
# Testing Accuracy: 89.88%
# -------------------------------
# Epoch 46: Training Loss: 0.043
# Training Accuracy: 99.50%
# Testing Accuracy: 89.25%
# -------------------------------
# Epoch 47: Training Loss: 0.048
# Training Accuracy: 98.88%
# Testing Accuracy: 88.75%
# -------------------------------
# Epoch 48: Training Loss: 0.049
# Training Accuracy: 99.09%
# Testing Accuracy: 89.75%
# -------------------------------
# Epoch 49: Training Loss: 0.059
# Training Accuracy: 98.78%
# Testing Accuracy: 89.00%
# -------------------------------
# Epoch 50: Training Loss: 0.062
# Training Accuracy: 98.81%
# Testing Accuracy: 89.00%
# -------------------------------
# Epoch 51: Training Loss: 0.045
# Training Accuracy: 99.19%
# Testing Accuracy: 89.50%
# -------------------------------
# Epoch 52: Training Loss: 0.037
# Training Accuracy: 99.62%
# Testing Accuracy: 89.12%
# -------------------------------
# Epoch 53: Training Loss: 0.041
# Training Accuracy: 99.25%
# Testing Accuracy: 88.75%
# -------------------------------
# Epoch 54: Training Loss: 0.047
# Training Accuracy: 98.06%
# Testing Accuracy: 87.62%
# -------------------------------
# Epoch 55: Training Loss: 0.045
# Training Accuracy: 98.78%
# Testing Accuracy: 89.12%
# -------------------------------
# Epoch 56: Training Loss: 0.048
# Training Accuracy: 99.66%
# Testing Accuracy: 89.38%
# -------------------------------
# Epoch 57: Training Loss: 0.030
# Training Accuracy: 99.78%
# Testing Accuracy: 89.62%
# -------------------------------
# Epoch 58: Training Loss: 0.030
# Training Accuracy: 99.69%
# Testing Accuracy: 89.25%
# -------------------------------
# Epoch 59: Training Loss: 0.026
# Training Accuracy: 99.62%
# Testing Accuracy: 89.00%
# -------------------------------
# Epoch 60: Training Loss: 0.031
# Training Accuracy: 99.81%
# Testing Accuracy: 89.25%
# -------------------------------
# Epoch 61: Training Loss: 0.033
# Training Accuracy: 99.00%
# Testing Accuracy: 89.75%
# -------------------------------
# Epoch 62: Training Loss: 0.036
# Training Accuracy: 99.31%
# Testing Accuracy: 88.88%
# -------------------------------
# Epoch 63: Training Loss: 0.043
# Training Accuracy: 99.72%
# Testing Accuracy: 88.88%
# -------------------------------
# Epoch 64: Training Loss: 0.036
# Training Accuracy: 98.97%
# Testing Accuracy: 89.12%
# -------------------------------
# Epoch 65: Training Loss: 0.033
# Training Accuracy: 99.78%
# Testing Accuracy: 89.00%
# -------------------------------
# Epoch 66: Training Loss: 0.027
# Training Accuracy: 99.91%
# Testing Accuracy: 89.50%
# -------------------------------
# Epoch 67: Training Loss: 0.027
# Training Accuracy: 99.38%
# Testing Accuracy: 88.38%
# -------------------------------
# Epoch 68: Training Loss: 0.023
# Training Accuracy: 100.00%
# Testing Accuracy: 89.50%
# -------------------------------
# Epoch 69: Training Loss: 0.018
# Training Accuracy: 99.84%
# Testing Accuracy: 90.00%
# -------------------------------
# Epoch 70: Training Loss: 0.018
# Training Accuracy: 99.97%
# Testing Accuracy: 88.88%
# -------------------------------
# Done!

# %% [markdown]
# **Author: Sai Chaitanya Mondi**
#
# **Date: April 23th, 2023**

# %%
yTrue1 = []
yPred1 = []

with torch.no_grad():
    for data in testLoader:
        inputs, labels = data
        outputs = model_temp(inputs)
        _, predicted = torch.max(outputs.data, 1)
        yTrue1 += labels.numpy().tolist()
        yPred1 += predicted.numpy().tolist()
        

# plotting
fig, ax = plt.subplots(ncols=2, figsize=(18, 7))

# first plot
disp1 = metrics.ConfusionMatrixDisplay.from_predictions(yTrue1, yPred1, display_labels=np.unique(birdLables), normalize='true')
disp1.plot(ax=ax[0], cmap=plt.cm.Blues, xticks_rotation='vertical', values_format='.2f')
ax[0].set_title('Confusion matrix - Proportion')

# second plot
confMat1 = metrics.confusion_matrix(yTrue1, yPred1)
dispMat1 = metrics.ConfusionMatrixDisplay(confusion_matrix=confMat1, display_labels=np.unique(birdLables))
dispMat1.plot(ax=ax[1], cmap='summer')
ax[1].set_title('Confusion matrix - Predicted Number')
ax[1].set_xticklabels(np.unique(birdLables), rotation='vertical')

plt.tight_layout()
plt.show()

# %%
# performance metrics - with more epochs

# F1 Score
f1Score1 = metrics.f1_score(yTrue1, yPred1, average = "weighted")
print(f"F1 Score is {f1Score1:0.2f}, means the model is correctly identifying the classes of the given dataset")
print(f"\n")

# Accuracy
modelAcc1 = metrics.accuracy_score(yTrue1, yPred1)
print(f"Model's accuracy is {modelAcc1 * 100:0.2f}%")
print(f"\n")

# Classification Report
classReport1 = metrics.classification_report(yTrue1, yPred1)
print(f"The Classification Report is as below:\n {classReport1}")
# Out:
# F1 Score is 0.89, means the model is correctly identifying the classes of the given dataset
#
#
# Model's accuracy is 88.88%
#
#
# The Classification Report is as below:
#                precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90       209
#            1       0.91      0.85      0.88       213
#            2       0.92      0.93      0.93       194
#            3       0.79      0.92      0.85       184
#
#     accuracy                           0.89       800
#    macro avg       0.89      0.89      0.89       800
# weighted avg       0.89      0.89      0.89       800
